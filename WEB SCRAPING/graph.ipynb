# %%
import importlib
import cities

# Force Jupyter to reload any edits made to cities.py
importlib.reload(cities)

# Access your scraped data directly
print(cities.df)
# Out:
#  World Temperatures — Weather Around The World
#
#
#  ---- MOST POPULAR CITIES DATA ----
#
# ...
